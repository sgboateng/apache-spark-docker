# %%
# Load from the path where the file is mounted in Jupyter
# Use the /home/spark/data path which is guaranteed to be shared
# with the workers via the Docker volume mounts.
df = spark.read.format("csv").load("file:///home/spark/data/data.csv")
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 # Load from the path where the file is mounted in Jupyter
#       2 # Use the /home/spark/data path which is guaranteed to be shared
#       3 # with the workers via the Docker volume mounts.
# ----> 4 df = spark.read.format("csv").load("file:///home/spark/data/data.csv")
#
# File /usr/local/lib/python3.8/dist-packages/pyspark/sql/readwriter.py:307, in DataFrameReader.load(self, path, format, schema, **options)
#     305 self.options(**options)
#     306 if isinstance(path, str):
# --> 307     return self._df(self._jreader.load(path))
#     308 elif path is not None:
#     309     if type(path) != list:
#
# File /usr/local/lib/python3.8/dist-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
# ...

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder \
    .master("spark://spark-master:7077") \
    .appName("Jupyter") \
    .getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/12/08 13:13:26 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/12/08 13:13:26 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://localhost:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>spark://spark-master:7077</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Jupyter</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
spark.sparkContext._jsc.sc().listJars()
# Out:
# JavaObject id=o36
# 25/12/08 13:27:49 WARN Dispatcher: Message RequestMessage(spark-master:7077, NettyRpcEndpointRef(spark://AppClient@d34179ca992c:34047), ExecutorAdded(0,worker-20251208124333-172.19.0.3-46353,172.19.0.3:46353,2,1024)) dropped due to sparkEnv is stopped. Could not find AppClient.
